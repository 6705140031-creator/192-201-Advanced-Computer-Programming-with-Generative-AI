# %% [markdown]
# <a href="https://colab.research.google.com/github/6705140031-creator/192-201-Advanced-Computer-Programming-with-Generative-AI/blob/main/3ndWeekClassWork.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance

    def deposit(self, amount):
        self.balance += amount

    def __str__(self):
        return f'{self.owner}: ${self.balance}'


acct = BankAccount('Min', 100)
acct.deposit(50)
print(acct)
# Out:
# Min: $150

# %%
acct = BankAccount('Min', 100)

acct.balance = -9999

print(acct)
# Out:
# Min: $-9999

# %%
class BankAccount:
    def __init__(self, owner, balance=0):
        if balance < 0:
            raise ValueError('balance cannot be negative')

        self.owner = owner
        self.balance = balance


good = BankAccount('Min', 100)
print(good.balance)
# Out:
# 100

# %%
class BankAccount:
    def __init__(self, owner, balance=0):
        if balance < 0:
            raise ValueError('balance cannot be negative')

        self.owner = owner
        self.balance = balance


bad = BankAccount('Min', -50)
print(good.balance)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1362/3764310178.py in <cell line: 0>()
#       8
#       9
# ---> 10 bad = BankAccount('Min', -50)
#      11 print(good.balance)
#
# /tmp/ipykernel_1362/3764310178.py in __init__(self, owner, balance)
#       2     def __init__(self, owner, balance=0):
#       3         if balance < 0:
# ----> 4             raise ValueError('balance cannot be negative')
#       5
#       6         self.owner = owner
#
# ValueError: balance cannot be negative

# %%
class BankAccount:
    def __init__(self, owner, balance=0):
        if balance < 0:
            raise ValueError('balance cannot be negative')

        self.owner = owner
        self.__balance = balance


acct = BankAccount('Min', 100)

print(acct.owner)
print(acct.__balance)
# Out:
# Mai
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_1362/4173984665.py in <cell line: 0>()
#      11
#      12 print(acct.owner)
# ---> 13 print(acct.__balance)
#
# AttributeError: 'BankAccount' object has no attribute '__balance'

# %%
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.set_balance(balance)

    def get_balance(self):
        return self.__balance

    def set_balance(self, amount):
        if amount < 0:
            raise ValueError('balance cannot be negative')

        self.__balance = amount


acct = BankAccount('Mai', 100)

print(acct.get_balance())

acct.set_balance(120)

print(acct.get_balance())
# Out:
# 100
# 120

# %%
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.set_balance(balance)

    def get_balance(self):
        return self.__balance

    def set_balance(self, amount):
        if amount < 0:
            raise ValueError('balance cannot be negative')

        self.__balance = amount


acct = BankAccount('Mai', 100)

print(acct.get_balance())

acct.set_balance(-10)

print(acct.get_balance())
# Out:
# 100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1362/360939886.py in <cell line: 0>()
#      18 print(acct.get_balance())
#      19
# ---> 20 acct.set_balance(-10)
#      21
#      22 print(acct.get_balance())
#
# /tmp/ipykernel_1362/360939886.py in set_balance(self, amount)
#       9     def set_balance(self, amount):
#      10         if amount < 0:
# ---> 11             raise ValueError('balance cannot be negative')
#      12
#      13         self.__balance = amount
#
# ValueError: balance cannot be negative

# %%
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.set_balance(balance)

    def get_balance(self):
        return self.__balance

    def set_balance(self, amount):
        if amount < 0:
            raise ValueError('balance cannot be negative')

        self.__balance = amount

    def deposit(self, amount):
        new_balance = self.get_balance() + amount
        self.set_balance(new_balance)


acct = BankAccount('Min', 100)

print(acct.get_balance())

acct.deposit(20)
print(acct.get_balance())

acct.deposit(50)
print(acct.get_balance())
# Out:
# 100
# 120
# 170

# %%
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance

    @property
    def balance(self):
        return self.__balance

    @balance.setter
    def balance(self, amount):
        if amount < 0:
            raise ValueError('balance cannot be negative')

        self.__balance = amount


acct = BankAccount('Mai', 100)

print(acct.balance)

acct.balance = 120

print(acct.balance)
# Out:
# 100
# 120

# %%
class BankAccount:
    def __init__(self, owner, balance=0):
        self.owner = owner
        self.balance = balance

    @property
    def balance(self):
        return self.__balance

    @balance.setter
    def balance(self, amount):
        if amount < 0:
            raise ValueError('balance cannot be negative')

        self.__balance = amount


acct = BankAccount('Mai', 100)

print(acct.balance)

acct.balance = -1

print(acct.balance)
# Out:
# 100
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1362/313296756.py in <cell line: 0>()
#      20 print(acct.balance)
#      21
# ---> 22 acct.balance = -1
#      23
#      24 print(acct.balance)
#
# /tmp/ipykernel_1362/313296756.py in balance(self, amount)
#      11     def balance(self, amount):
#      12         if amount < 0:
# ---> 13             raise ValueError('balance cannot be negative')
#      14
#      15         self.__balance = amount
#
# ValueError: balance cannot be negative

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    @property
    def name(self):
        return self.__name

    @name.setter
    def name(self, value):
        if value == '':
            raise ValueError('name cannot be empty')

        self.__name = value

    @property
    def age(self):
        return self.__age

    @age.setter
    def age(self, value):
        if value < 1 or value > 120:
            raise ValueError('age out of range')

        self.__age = value

    def __str__(self):
        return f'{self.name} (age {self.age})'


s = Student('Min', 22)

print(s)
# Out:
# Min (age 22)

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    @property
    def name(self):
        return self.__name

    @name.setter
    def name(self, value):
        if value == '':
            raise ValueError('name cannot be empty')

        self.__name = value

    @property
    def age(self):
        return self.__age

    @age.setter
    def age(self, value):
        if value < 1 or value > 120:
            raise ValueError('age out of range')

        self.__age = value

    def __str__(self):
        return f'{self.name} (age {self.age})'


s = Student('Min', 200)

print(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1362/2287405964.py in <cell line: 0>()
#      30
#      31
# ---> 32 s = Student('Min', 200)
#      33
#      34 print(s)
#
# /tmp/ipykernel_1362/2287405964.py in __init__(self, name, age)
#       2     def __init__(self, name, age):
#       3         self.name = name
# ----> 4         self.age = age
#       5
#       6     @property
#
# /tmp/ipykernel_1362/2287405964.py in age(self, value)
#      22     def age(self, value):
#      23         if value < 1 or value > 120:
# ---> 24             raise ValueError('age out of range')
#      25
#      26         self.__age = value
#
# ValueError: age out of range

# %%
class Student:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    @property
    def name(self):
        return self.__name

    @name.setter
    def name(self, value):
        if value == '':
            raise ValueError('name cannot be empty')

        self.__name = value

    @property
    def age(self):
        return self.__age

    @age.setter
    def age(self, value):
        if value < 1 or value > 120:
            raise ValueError('age out of range')

        self.__age = value

    def __str__(self):
        return f'{self.name} (age {self.age})'


s = Student('', 22)

print(s)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipykernel_1362/3424496294.py in <cell line: 0>()
#      30
#      31
# ---> 32 s = Student('', 22)
#      33
#      34 print(s)
#
# /tmp/ipykernel_1362/3424496294.py in __init__(self, name, age)
#       1 class Student:
#       2     def __init__(self, name, age):
# ----> 3         self.name = name
#       4         self.age = age
#       5
#
# /tmp/ipykernel_1362/3424496294.py in name(self, value)
#      11     def name(self, value):
#      12         if value == '':
# ---> 13             raise ValueError('name cannot be empty')
#      14
#      15         self.__name = value
#
# ValueError: name cannot be empty
